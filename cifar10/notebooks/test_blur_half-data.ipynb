# %%
# %matplotlib inline

# %%
import sys 
sys.path.append('../')
import matplotlib.pyplot as plt
import numpy as np
import torch
import torchvision
import cv2

from blurnet.utils import dataloader, GaussianBlurAll

# %%
def imshow(img, title='',filename='', scale=True):
    img = img / 2 + 0.5     # unnormalize
    if type(img) == torch.Tensor:
        img = img.numpy()
        plt.imshow(np.transpose(img, (1, 2, 0)))
    else:  # if type(img) == numpy.ndarray
        plt.imshow(img)
    if not scale:
        plt.xticks([])  # if you want to remove scale axes
        plt.yticks([])
    if title:
        plt.title(title)
    if filename:
        plt.savefig(filename)  # added for saving the image
    plt.show()

# %%
trainloader, testloader, classes = dataloader(32)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()

# %%
# show images
imshow(torchvision.utils.make_grid(images))

# %%
half = images.size(0) // 2
images[:half].size()
# Out:
# torch.Size([16, 3, 32, 32])

# %%
images.chunk(2)[0].size()
# Out:
# torch.Size([16, 3, 32, 32])

# %%
half1, half2 = images.chunk(2)

# %%
half1.size()
# Out:
# torch.Size([16, 3, 32, 32])

# %%
torch.cat((half1, half2))
# Out:
# tensor([[[[ 1.0000,  0.9765,  0.9765,  ...,  0.9765,  0.9765,  1.0000],
#           [ 1.0000,  0.9765,  0.9765,  ...,  0.9608,  0.9608,  0.9843],
#           [ 1.0000,  0.9922,  0.9922,  ...,  0.9765,  0.9686,  1.0000],
#           ...,
#           [-0.0510, -0.0667, -0.0510,  ..., -0.0353, -0.0431, -0.0353],
#           [-0.0353, -0.0588, -0.0824,  ..., -0.0118, -0.0353, -0.0353],
#           [ 0.0039, -0.0196, -0.0196,  ..., -0.0118, -0.0118, -0.0118]],
#
#          [[ 1.0000,  0.9765,  0.9765,  ...,  0.9765,  0.9765,  1.0000],
#           [ 1.0000,  0.9765,  0.9765,  ...,  0.9608,  0.9608,  0.9843],
#           [ 1.0000,  0.9922,  0.9922,  ...,  0.9765,  0.9686,  1.0000],
#           ...,
#           [-0.0510, -0.0667, -0.0510,  ..., -0.0353, -0.0431, -0.0353],
#           [-0.0353, -0.0588, -0.0824,  ..., -0.0118, -0.0353, -0.0353],
#           [ 0.0039, -0.0196, -0.0196,  ..., -0.0118, -0.0118, -0.0118]],
#
#          [[ 1.0000,  0.9765,  0.9765,  ...,  0.9765,  0.9765,  1.0000],
#           [ 1.0000,  0.9765,  0.9765,  ...,  0.9608,  0.9608,  0.9843],
#           [ 1.0000,  0.9922,  0.9922,  ...,  0.9765,  0.9686,  1.0000],
#           ...,
#           [-0.0510, -0.0667, -0.0510,  ..., -0.0353, -0.0431, -0.0353],
#           [-0.0353, -0.0588, -0.0824,  ..., -0.0118, -0.0353, -0.0353],
#           [ 0.0039, -0.0196, -0.0196,  ..., -0.0118, -0.0118, -0.0118]]],
#
#
#         [[[ 0.5922,  0.1843, -0.3020,  ...,  0.5686,  0.5451,  0.5373],
#           [ 0.7333,  0.7490,  0.4745,  ...,  0.5529,  0.5294,  0.5294],
#           [ 0.7255,  0.7176,  0.7176,  ...,  0.5608,  0.5451,  0.5373],
#           ...,
#           [-0.3490, -0.3098, -0.2392,  ..., -0.5451, -0.4275, -0.8510],
#           [-0.2706, -0.2471, -0.2314,  ..., -0.7725, -0.5765, -0.8824],
#           [-0.3255, -0.2471, -0.2784,  ..., -0.9137, -0.8431, -0.8902]],
#
#          [[ 0.6078,  0.1686, -0.3255,  ...,  0.6078,  0.5922,  0.5843],
#           [ 0.7412,  0.7490,  0.4510,  ...,  0.5843,  0.5765,  0.5686],
#           [ 0.7176,  0.7176,  0.7098,  ...,  0.5843,  0.5843,  0.5765],
#           ...,
#           [-0.5059, -0.5216, -0.5059,  ..., -0.7255, -0.6314, -0.8353],
#           [-0.8196, -0.8824, -0.9294,  ..., -0.8902, -0.6784, -0.8902],
#           [-1.0000, -1.0000, -0.9922,  ..., -0.9451, -0.8667, -0.9216]],
#
#          [[ 0.6314,  0.1608, -0.3647,  ...,  0.6314,  0.6157,  0.6157],
#           [ 0.7569,  0.7569,  0.4510,  ...,  0.6078,  0.6000,  0.6000],
#           [ 0.7490,  0.7412,  0.7176,  ...,  0.6157,  0.6078,  0.6078],
#           ...,
#           [-0.5529, -0.5529, -0.5529,  ..., -0.7725, -0.6941, -0.8745],
#           [-0.8196, -0.8667, -0.9294,  ..., -0.8980, -0.7020, -0.9294],
#           [-1.0000, -0.9922, -0.9686,  ..., -0.9529, -0.8745, -0.9529]]],
#
#
#         [[[ 0.1294,  0.3961,  0.4745,  ..., -0.5216, -0.3647,  0.0588],
#           [ 0.1529,  0.3098,  0.3176,  ..., -0.4118, -0.4353, -0.3412],
#           [ 0.0196,  0.1608,  0.3882,  ..., -0.4745, -0.3882, -0.4824],
#           ...,
#           [-0.4275, -0.1922,  0.1137,  ..., -0.0275,  0.0196, -0.3176],
#           [-0.4353, -0.3020, -0.2235,  ...,  0.1922, -0.0902, -0.2549],
#           [-0.3333, -0.4745, -0.5608,  ..., -0.0902, -0.1843, -0.0667]],
#
#          [[-0.0353,  0.1843,  0.2471,  ..., -0.4510, -0.3569, -0.0196],
#           [ 0.0431,  0.1451,  0.1137,  ..., -0.3098, -0.3725, -0.3569],
#           [-0.0510,  0.0353,  0.2078,  ..., -0.3490, -0.2941, -0.4667],
#           ...,
#           [-0.6078, -0.2627,  0.0980,  ..., -0.0353,  0.0118, -0.3176],
#           [-0.6314, -0.3569, -0.2157,  ...,  0.1608, -0.1137, -0.2627],
#           [-0.5216, -0.5137, -0.5373,  ..., -0.1608, -0.2235, -0.0745]],
#
#           [ 0.2157,  0.2471,  0.3020,  ..., -0.3333, -0.3725, -0.5373],
#           [ 0.2314,  0.2627,  0.3020,  ..., -0.4510, -0.5765, -0.6392],
#           ...,
#           [-0.2627, -0.3961, -0.0980,  ..., -0.3020, -0.0118, -0.1373],
#           [-0.5373, -0.4275, -0.3020,  ..., -0.3490, -0.1843, -0.3333],
#           [-0.4667, -0.3725, -0.3804,  ..., -0.3569, -0.3098, -0.3569]],
#
#          [[ 0.1922,  0.2235,  0.2784,  ..., -0.7490, -0.6392, -0.7176],
#           [ 0.1922,  0.2235,  0.2784,  ..., -0.7333, -0.6863, -0.7961],
#           [ 0.2078,  0.2392,  0.2784,  ..., -0.7176, -0.7961, -0.8275],
#           ...,
#           [-0.2706, -0.4039, -0.1059,  ..., -0.3098, -0.0196, -0.1451],
#           [-0.5451, -0.4353, -0.3098,  ..., -0.3647, -0.1922, -0.3412],
#           [-0.4745, -0.3804, -0.3882,  ..., -0.3647, -0.3176, -0.3647]]],
#
#
#         [[[-0.6000, -0.4118, -0.3098,  ...,  0.9765,  0.9765,  0.9765],
#           [-0.5843, -0.4510, -0.2314,  ...,  1.0000,  1.0000,  1.0000],
#           [-0.5216, -0.4510, -0.2627,  ...,  0.9922,  0.9765,  0.9451],
#           ...,
#           [ 0.7882,  0.7961,  0.3882,  ...,  0.3725,  0.1608, -0.3647],
#           [ 0.7882,  0.8196,  0.5216,  ...,  0.2235,  0.0275, -0.0039],
#           [ 0.6941,  0.7176,  0.2000,  ..., -0.2157, -0.1765, -0.0118]],
#
#          [[-0.4510, -0.2078, -0.0902,  ...,  0.9765,  0.9765,  0.9765],
#           [-0.4510, -0.2549, -0.0196,  ...,  1.0000,  1.0000,  1.0000],
#           [-0.3882, -0.2706, -0.0667,  ...,  0.9922,  0.9765,  0.9529],
#           ...,
#           [ 0.6392,  0.6392,  0.3333,  ...,  0.2784,  0.0510, -0.4196],
#           [ 0.5922,  0.6392,  0.3882,  ...,  0.1294,  0.0196, -0.0431],
#           [ 0.5059,  0.5216,  0.0667,  ..., -0.2627, -0.1686, -0.0588]],
#
#          [[-0.6157, -0.4980, -0.4588,  ...,  0.9765,  0.9765,  0.9765],
#           [-0.6078, -0.5451, -0.4118,  ...,  1.0000,  1.0000,  1.0000],
#           [-0.5922, -0.5765, -0.4196,  ...,  0.9843,  0.9686,  0.9373],
#           ...,
#           [ 0.4353,  0.4196,  0.3020,  ...,  0.1373, -0.0510, -0.4745],
#           [ 0.4039,  0.4353,  0.2706,  ...,  0.0745, -0.0039, -0.1373],
#           [ 0.3176,  0.3255, -0.0275,  ..., -0.2627, -0.1216, -0.0745]]]])

# %%
half1_blur = GaussianBlurAll(half1, (7,7), 1)

# %%
output = torch.cat((half1_blur, half2))

# %%
# show images
imshow(torchvision.utils.make_grid(output), filename='./images/blur-half-data.png', scale=False)
